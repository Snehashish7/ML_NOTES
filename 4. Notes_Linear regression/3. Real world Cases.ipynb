# %% [markdown]
# **Better to study this from video (just 7 min)**
#
# ![image.png](attachment:image.png)
# Mistake at 00:12, there is no problem of imbalanced data in linear regression as there are no class labels.
#
# ![image-2.png](attachment:image-2.png)
#
# (RANSAC - Random sample consensus)
# ![image-3.png](attachment:image-3.png)
