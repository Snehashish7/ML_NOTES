# %% [markdown]
# ![image.png](attachment:image.png)
#
# Why not KS statistics which we learned in statistics?
#  - we can't do derivative of the KS supremo hence whole KS fn has no derivative.
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
