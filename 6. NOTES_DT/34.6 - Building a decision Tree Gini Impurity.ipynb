# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# if both are same except their scale then why Gini Impurity over Entropy?
# ![image-3.png](attachment:image-3.png)
#
# (don't confuse btn the notations of Gini Impurity and Information Gain)
