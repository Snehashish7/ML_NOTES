# %% [markdown]
# ![image.png](attachment:image.png)
#
# In LR we compute dist of pt from hyperplane, in KNN we compute dist btn two pts so we nees FT(Feat. Trans) to normalize different scales that the distances may be in.<br>
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# DTs are based on order of feature not on distance hence no need of FT.
