# %% [markdown]
# When the features can be represented using different scales then it is better to standardize the data/column before performing any ops. (Example if cols are distance values then it can be repr using diferent metrics (m, km, cm, etc...))
#
# - In our case the cols are distance from point to hyperplane
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
