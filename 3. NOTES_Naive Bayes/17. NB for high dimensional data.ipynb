# %% [markdown]
# ![image.png](attachment:image.png)
#
# Naive bias can be very well used for high dimensional data, since we know it is extensively used for text classification ( each text vector may have very high dimensional vectors of words).
#
# We must be cautious not to use raw probabilities rather log-probabilities to make it numerically stable.
